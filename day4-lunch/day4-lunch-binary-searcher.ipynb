# %%
###Open file

###For line in file:
####Skip first 5 lines (header lines)
####Split the lines into list
####Chromosome, starting position, 
#### ending position, gene_name, feature_type, 
####gene_biotype (protein coding)
####Only store protein-coding genes

## search_pos = 21378950

### lo = 0

### high = len(list)-1

### mid = middle index

## once define the mid, index it in our data and compare


##while True:
    ##if high = low+1
        ##find distance to end of lo
        ##find distance to start of high
        ##compare, figure out which is closest
        ##output gene_name
        ##break
## if search_pos < stored_data[mid][1]:
   ##high = mid
    ##mid = high+low/2

## elif search_pos > stored_data[mid][1]:
##    low = mid
##    mid = (high+low)/2

## else:
    ## found the gene
    ## output print gene_name
    ##Break

# %%
fh = open('/Users/cmdb/qbb2020-answers/day3-hw/BDGP6.Ensembl.81.gtf', 'r')


pgene_list = []

##counter=0
for line in fh:
    ##if counter < 2:
    if '3R' in line:
        if 'protein_coding' in line:
            line_split = line.split()
            if line_split[2] == 'gene':
                pgene_list.append([line_split[0], int(line_split[3]),
                                    int(line_split[4]), (line_split[-5])[1:-2]])
counter = 0
                
position = 21378950

low = 0

high = len(pgene_list)-1

middlei = (len(pgene_list)//2)

found = False

while not found:
    
    if high == (low + 1):
        low_check = position - (pgene_list[low][2])
        high_check = (pgene_list[high][1]) - position
    
        if low_check < high_check:
            ##print('low_check shorter')
            ##print(pgene_list[low])
            print('Nearest gene name: ' + (pgene_list[low][3]))
            print('Distance from 3R:21,378950: ' + str(low_check) + ' bp')
            ##counter += 1
            break
    
        elif low_check > high_check:
            ##print('high_check shorter')
            ##print(pgene_list[high])
            print('Nearest gene name: ' + (pgene_list[high][3]))
            print('Distance from 3R:21,378950: ' + str(high_check) + ' bp')
            ##counter += 1
            break
    

    elif position > pgene_list[middlei][2]:
        low = middlei
        middlei = ((high+low)//2)
        counter += 1
    

    elif position < pgene_list[middlei][1]:
        high = middlei
        middlei = ((high+low)//2)
        counter += 1
    
    else:
        print('Found a match!')
        print(str('Gene name: ') + pgene_list[middlei][3])
        ##counter += 1
        break
    
print('Number of iterations: '+ str(counter))
    
    

##if pgene_list[middlei] == position:
    ##found = True
    
    
    
    
    
        
                ##counter += 1
##print(pgene_list)

##'3R' in pgene_list[1][0]
##print(pgene_list[1][0])
# Out:
# Nearest gene name: tin
# Distance from 3R:21,378950: 27 bp
# Number of iterations: 12

# %%
position = 21378950

# %%
high_end
# Out:
# 8032

# %%
low_end
# Out:
# -5375

# %%
print(high)
print(low)
print(middlei)
# Out:
# 2104
# 2103
# 2103

# %%
##print(len(pgene_list))
print(pgene_list)
high
low
middlei
# Out:
# [['3R', 835381, 2503907, 'FBgn0267431'], ['3R', 2554124, 3263573, 'FBgn0267430'], ['3R', 3322810, 3354486, 'FBgn0086917'], ['3R', 3461351, 3587054, 'FBgn0010247'], ['3R', 3623143, 3627690, 'FBgn0086378'], ['3R', 3734855, 3745306, 'FBgn0263977'], ['3R', 3750363, 3752353, 'FBgn0069923'], ['3R', 3846729, 3868401, 'FBgn0039955'], ['3R', 4077939, 4104326, 'FBgn0259821'], ['3R', 4126442, 4137882, 'FBgn0027341'], ['3R', 4160610, 4162235, 'FBgn0058198'], ['3R', 4174632, 4186751, 'FBgn0037213'], ['3R', 4189692, 4190260, 'FBgn0000500'], ['3R', 4197206, 4204572, 'FBgn0037215'], ['3R', 4204493, 4215314, 'FBgn0037217'], ['3R', 4211783, 4227518, 'FBgn0037218'], ['3R', 4218463, 4220130, 'FBgn0051516'], ['3R', 4227387, 4229238, 'FBgn0261436'], ['3R', 4230779, 4232342, 'FBgn0037220'], ['3R', 4233047, 4235041, 'FBgn0015331'], ['3R', 4235217, 4241057, 'FBgn0010225'], ['3R', 4241045, 4242717, 'FBgn0037222'], ['3R', 4242785, 4243146, 'FBgn0085334'], ['3R', 4247020, 4248313, 'FBgn0037224'], ['3R', 4248723
# ...

# %%
fh = open('/Users/cmdb/qbb2020-answers/day3-hw/BDGP6.Ensembl.81.gtf', 'r')


pgene_list = []

counter=0
for line in fh:
    if '#!' not in line:
        if counter < 12:
            print((line.split())[-5])
            counter+=1
# Out:
# "CR41571";
# "CR41571-RA";
# "pseudogene";
# "CG45784";
# "CG45784-RA";
# "protein_coding";
# "protein_coding";
# "CG45784-RA";
# "protein_coding";
# "protein_coding";
# "protein_coding";
# "protein_coding";

# %%
fh = open('/Users/cmdb/qbb2020-answers/day3-hw/BDGP6.Ensembl.81.gtf', 'r')


pgene_list = []

##counter=0
for line in fh:
    ##if counter < 2:
    if '3R' in line:
        if 'protein_coding' in line:
            line_split = line.split()
            if line_split[2] == 'gene':
                pgene_list.append([line_split[0], int(line_split[3]),
                                    int(line_split[4]), (line_split[9])[1:-2]])
                
position = 21378950

low = 0

high = len(pgene_list)-1

middlei = 0
                
        
        
                ##counter += 1
##print(pgene_list)

##'3R' in pgene_list[1][0]
##print(pgene_list[1][0])
